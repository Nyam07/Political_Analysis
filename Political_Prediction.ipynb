# %% [markdown]
# # Project to predict the popularity of Political leaders and detect hate speech and tribalism from Facebook and Twitter comments

# %% [markdown]
# ## Imports

# %%
from webdriver_manager.chrome import ChromeDriverManager

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

from bs4 import BeautifulSoup

import pandas as pd

import time

# for tweets collection
import tweepy

# text cleaning
import preprocessor as p

# text preprocessing
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.corpus import wordnet

#lemmatization
from nltk.stem import WordNetLemmatizer

#sentiment analysis
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk.tag import pos_tag

## visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# get the language of the text
import langdetect
#for ner recognition
import spacy

# %% [markdown]
# # GET FACEBOOK COMMENTS

# %%
# scroll down
def scroll():
    driver.find_element(By.TAG_NAME, 'body').send_keys(Keys.END)
    time.sleep(3)
    pop_out_btn = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.ID, "popup_xout")))
    pop_out_btn.click()

# %%
# funtion to click the view more button
def view_more_click(driver):
    try: 
        view_more_comments = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.LINK_TEXT, "View more comments…")))
        view_more_comments.click()
    
    except TimeoutException:
        view_more_comments = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.LINK_TEXT, "View previous comments…")))
        view_more_comments.click()
    
    except (NoSuchElementException, ElementClickInterceptedException, StaleElementReferenceException) :
        print("Problem found")
    html = driver.page_source
    return html

# function to click the button 50 times
def view_more_comm(driver):
    i = 0
    while i < 50:
        html = view_more_click(driver)
        time.sleep(3)
        i += 1
    return html

# %%
# function to get a list of all the comment elements
def get_comments(html):
    soup = BeautifulSoup(html, 'html.parser')
    comment_section = soup.find("div", {"class":"_59e9 _1-ut _2a_g _34oh" })
    comment_els = comment_section.find_all("div", {"class":"_2a_i"})
    
    master_list = []
    for c in comment_els:
        data_dict = {}
        data_dict["User"] = c.find("div", {"class":"_2b05"}).text
        data_dict["Comment"] = c.find("div", {"data-sigil":"comment-body"}).text
        master_list.append(data_dict)
    return master_list

# %% [markdown]
# # GETTING TWITTER DATA

# %% [markdown]
# ## Twitter Authentication

# %%
# read the keys from the file 
def authorize_twitter():
    keys = []
    with open('../Keys.txt') as f:
        for line in f:
            keys.append(line.strip())

    API_KEY = keys[1]
    API_KEY_SECRET = keys [4]
    ACCESS_TOKEN = keys[10]
    ACCESS_TOKEN_SECRET = keys[13]
    
    # initialize the api
    auth = tweepy.OAuthHandler(API_KEY, API_KEY_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
    api = tweepy.API(auth)
    
    return (api)

# %% [markdown]
# ## Get the replies from the posts

# %%
def get_replies(url):
    name = url.split("/")[-3]
    tweet_id = url.split("/")[-1]

    #empty list for the replies
    replies = []
    
    api = authorize_twitter()
    # get replies from the tweet
    for tweet in tweepy.Cursor(api.search_tweets,q='to:'+name, result_type='recent').items(1000):
        if hasattr(tweet, 'in_reply_to_status_id_str'):
            if (tweet.in_reply_to_status_id_str==tweet_id):
                replies.append(tweet)
    
    #master list to hold all the data needed
    master_list = []
    for reply in replies:
        data_dict = {}
        data_dict["User"] = reply.author.screen_name
        data_dict["Comment"] = reply.text

        master_list.append(data_dict)
        
    return (master_list)

# %% [markdown]
# # TEXT PREPROCESSING

# %% [markdown]
# ## Tokenization and POS tagging + removing stop words

# %%
#perform tokenization and pos tagging and remove stop words
pos_dict = {'J': wordnet.ADJ, 'v': wordnet.VERB, 'N': wordnet.NOUN, 'R': wordnet.ADV}
def token_stop_pos(text):
    tags = pos_tag(word_tokenize(text))
    newlist = []
    
    for word, tag in tags:
        if word.lower() not in set(stopwords.words('english')):
            newlist.append(tuple([word, pos_dict.get(tag[0])]))
            
    return newlist

# %% [markdown]
# ## Lemmatization

# %%
wordnet_lemmatizer = WordNetLemmatizer()
def lemmatize(pos_data):
    lemma_rew = " "
    for word, pos in pos_data:
        if not pos:
            lemma = word
            lemma_rew = lemma_rew + " " + lemma
        else:
            lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
            lemma_rew = lemma_rew + " " + lemma
    return lemma_rew

# %% [markdown]
# ## SENTIMENT ANALYSIS USING VADER

# %%
def vaderSentimentAnalysis(text):
    analyzer = SentimentIntensityAnalyzer()
    vs= analyzer.polarity_scores(text)
    return vs['compound']

# function to analyse 
def vader_analysis(compound):
    if compound > 0:
        return 'Positive'
    elif compound < 0 :
        return 'Negative'
    else:
        return 'Neutral'

# %% [markdown]
# ## Get names and parties from the text

# %%
def get_parties(text):
    for i in range(len(text)):
        parties=[]
        tags = text[i][1]
        if tags == "POLITICAL_PARTY":
            party = text[i][0]
            if party not in parties:
                parties.append(party)
        else:
            continue
        return parties

# %%
def get_names(text):
    names=[]
    for i in range(len(text)):
        tags = text[i][1]
        if tags == "POLITICIAN":
            name = text[i][0]
            if name not in names:
                names.append(name)
        else:
            continue
    return names

# %% [markdown]
# # MAIN FILE

# %%
choice = input("Please select the choice of your data. \n 1. for facebook. \n 2. For twitter")
if choice == "1":
    # install webdriver
    driver = webdriver.Chrome(ChromeDriverManager().install())
    url = input("Paste the Facebook mobile url: ")
    driver.get(url)
    scroll()

    print("Getting comments please wait...\n")
    html = view_more_comm(driver)

    master_list = get_comments(html)

    print(str(len(master_list)) + " Comments found")
        
else:
    url = input("Paste the tweet url: ")
    print("----Getting replies please wait------")
    master_list = get_replies(url)
    print(str(len(master_list)) + " Comments found")
        
    
    #create a dataframe
df = pd.DataFrame(master_list)
df["clean_tweets"] = df["Comment"].apply(lambda x: p.clean(x))
df
# Out:
# Please select the choice of your data.
#  1. for facebook.
#  2. For twitter1
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [C:\Users\NYAM\.wdm\drivers\chromedriver\win32\99.0.4844.51\chromedriver.exe] found in cache
# C:\Users\NYAM\AppData\Local\Temp/ipykernel_2268/2026771453.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# Paste the Facebook mobile url: https://mobile.facebook.com/NTVKenya/photos/a.80240814057/10157943885044058/?type=3&source=48
# Getting comments please wait...
#
# 338 Comments found
#                User                                            Comment  \
# 0       Trojans War  At least you have confirmed to us that someone...
# 1     Carole Otieno  Master of lies ....after raila impeached Uhuru...
# 2     Ochieng Owaga  Raila could not impeach Uhuru so that you bene...
# 3    Philemon Liech  Ruto can say anything now that his ill plans h...
# 4      Erick Moturi  Mr Promises is a dangerous kalenjinga. Can do ...
# ..              ...                                                ...
# 333  Brayoo Wiseman                                   Ruto is confused
# 334  Njeri Anjeline                                Stop that nonsense.
# 335    William Ouma  So Raila wanted to impeach Uhuru so that Ruto ...
# 336     Zipsy Ndush          Philemon Liech kumbe unaenda muchene hivo
# 337     Zipsy Ndush     Philemon Liech Hii haitatufanya tuingie Azimio
#
#                                           clean_tweets
# 0    At least you have confirmed to us that someone...
# 1    Master of lies ....after raila impeached Uhuru...
# 2    Raila could not impeach Uhuru so that you bene...
# 3    Ruto can say anything now that his ill plans h...
# 4    Mr Promises is a dangerous kalenjinga. Can do ...
# ..                                                 ...
# 333                                   Ruto is confused
# 334                                Stop that nonsense.
# 335  So Raila wanted to impeach Uhuru so that Ruto ...
# 336          Philemon Liech kumbe unaenda muchene hivo
# 337     Philemon Liech Hii haitatufanya tuingie Azimio
#
# [338 rows x 3 columns]

# %% [markdown]
# ## Text Preprocessing

# %%
df['POS tagged'] = df['clean_tweets'].apply(lambda x: token_stop_pos(x))
df
# Out:
#                User                                            Comment  \
# 0       Trojans War  At least you have confirmed to us that someone...
# 1     Carole Otieno  Master of lies ....after raila impeached Uhuru...
# 2     Ochieng Owaga  Raila could not impeach Uhuru so that you bene...
# 3    Philemon Liech  Ruto can say anything now that his ill plans h...
# 4      Erick Moturi  Mr Promises is a dangerous kalenjinga. Can do ...
# ..              ...                                                ...
# 333  Brayoo Wiseman                                   Ruto is confused
# 334  Njeri Anjeline                                Stop that nonsense.
# 335    William Ouma  So Raila wanted to impeach Uhuru so that Ruto ...
# 336     Zipsy Ndush          Philemon Liech kumbe unaenda muchene hivo
# 337     Zipsy Ndush     Philemon Liech Hii haitatufanya tuingie Azimio
#
#                                           clean_tweets  \
# 0    At least you have confirmed to us that someone...
# 1    Master of lies ....after raila impeached Uhuru...
# 2    Raila could not impeach Uhuru so that you bene...
# 3    Ruto can say anything now that his ill plans h...
# 4    Mr Promises is a dangerous kalenjinga. Can do ...
# ..                                                 ...
# 333                                   Ruto is confused
# 334                                Stop that nonsense.
# 335  So Raila wanted to impeach Uhuru so that Ruto ...
# 336          Philemon Liech kumbe unaenda muchene hivo
# 337     Philemon Liech Hii haitatufanya tuingie Azimio
#
#                                             POS tagged
# 0    [(least, a), (confirmed, None), (us, None), (s...
# 1    [(Master, n), (lies, n), (...., None), (raila,...
# 2    [(Raila, n), (could, None), (impeach, None), (...
# 3    [(Ruto, n), (say, None), (anything, n), (ill, ...
# 4    [(Mr, n), (Promises, n), (dangerous, a), (kale...
# ..                                                 ...
# 333                      [(Ruto, n), (confused, None)]
# 334           [(Stop, None), (nonsense, n), (., None)]
# 335  [(Raila, n), (wanted, None), (impeach, None), ...
# 336  [(Philemon, n), (Liech, n), (kumbe, None), (un...
# 337  [(Philemon, n), (Liech, n), (Hii, n), (haitatu...
#
# [338 rows x 4 columns]

# %%
# Lemmatization
df['Lemma'] = df['POS tagged'].apply(lambda x: lemmatize(x))
df.head()
# Out:
#              User                                            Comment  \
# 0     Trojans War  At least you have confirmed to us that someone...
# 1   Carole Otieno  Master of lies ....after raila impeached Uhuru...
# 2   Ochieng Owaga  Raila could not impeach Uhuru so that you bene...
# 3  Philemon Liech  Ruto can say anything now that his ill plans h...
# 4    Erick Moturi  Mr Promises is a dangerous kalenjinga. Can do ...
#
#                                         clean_tweets  \
# 0  At least you have confirmed to us that someone...
# 1  Master of lies ....after raila impeached Uhuru...
# 2  Raila could not impeach Uhuru so that you bene...
# 3  Ruto can say anything now that his ill plans h...
# 4  Mr Promises is a dangerous kalenjinga. Can do ...
#
#                                           POS tagged  \
# 0  [(least, a), (confirmed, None), (us, None), (s...
# 1  [(Master, n), (lies, n), (...., None), (raila,...
# 2  [(Raila, n), (could, None), (impeach, None), (...
# 3  [(Ruto, n), (say, None), (anything, n), (ill, ...
# 4  [(Mr, n), (Promises, n), (dangerous, a), (kale...
#
#                                                Lemma
# 0    least confirmed us someone wanted impeach pr...
# 1    Master lie .... raila impeached Uhuru benefi...
# 2    Raila could impeach Uhuru benefit ... 're fo...
# 3    Ruto say anything ill plan exposed .. danger...
# 4    Mr Promises dangerous kalenjinga . anything ...

# %% [markdown]
# ## Get only english text

# %%
df['language'] = df['clean_tweets'].apply(lambda x: langdetect.detect(x) if x.strip()!="" else "")
df = df[df['language']=='en'].reset_index(drop=True)
df.drop('language', axis=1)
df
# Out:
#                 User                                            Comment  \
# 0        Trojans War  At least you have confirmed to us that someone...
# 1      Carole Otieno  Master of lies ....after raila impeached Uhuru...
# 2      Ochieng Owaga  Raila could not impeach Uhuru so that you bene...
# 3     Philemon Liech  Ruto can say anything now that his ill plans h...
# 4       Erick Moturi  Mr Promises is a dangerous kalenjinga. Can do ...
# ..               ...                                                ...
# 223    Jira Mwenyewe                                     For what gains
# 224  Nkhbitu Micheni                     Mr promise say another promise
# 225   Brayoo Wiseman                                   Ruto is confused
# 226   Njeri Anjeline                                Stop that nonsense.
# 227     William Ouma  So Raila wanted to impeach Uhuru so that Ruto ...
#
#                                           clean_tweets  \
# 0    At least you have confirmed to us that someone...
# 1    Master of lies ....after raila impeached Uhuru...
# 2    Raila could not impeach Uhuru so that you bene...
# 3    Ruto can say anything now that his ill plans h...
# 4    Mr Promises is a dangerous kalenjinga. Can do ...
# ..                                                 ...
# 223                                     For what gains
# 224                     Mr promise say another promise
# 225                                   Ruto is confused
# 226                                Stop that nonsense.
# 227  So Raila wanted to impeach Uhuru so that Ruto ...
#
#                                             POS tagged  \
# 0    [(least, a), (confirmed, None), (us, None), (s...
# 1    [(Master, n), (lies, n), (...., None), (raila,...
# 2    [(Raila, n), (could, None), (impeach, None), (...
# 3    [(Ruto, n), (say, None), (anything, n), (ill, ...
# 4    [(Mr, n), (Promises, n), (dangerous, a), (kale...
# ..                                                 ...
# 223                                       [(gains, n)]
# 224  [(Mr, n), (promise, n), (say, None), (another,...
# 225                      [(Ruto, n), (confused, None)]
# 226           [(Stop, None), (nonsense, n), (., None)]
# 227  [(Raila, n), (wanted, None), (impeach, None), ...
#
#                                                  Lemma language
# 0      least confirmed us someone wanted impeach pr...       en
# 1      Master lie .... raila impeached Uhuru benefi...       en
# 2      Raila could impeach Uhuru benefit ... 're fo...       en
# 3      Ruto say anything ill plan exposed .. danger...       en
# 4      Mr Promises dangerous kalenjinga . anything ...       en
# ..                                                 ...      ...
# 223                                               gain       en
# 224                     Mr promise say another promise       en
# 225                                      Ruto confused       en
# 226                                    Stop nonsense .       en
# 227          Raila wanted impeach Uhuru Ruto takes lol       en
#
# [228 rows x 6 columns]

# %% [markdown]
# ## Geta clean dataframe for text analysis

# %%
fin_data= pd.DataFrame(df[['Comment', 'Lemma']])

# %% [markdown]
# ## Sentiment Analysis

# %%
fin_data['Vader_Sentiment'] = fin_data['Comment'].apply(lambda x: vaderSentimentAnalysis(x))
fin_data['Vader_Analysis'] = fin_data['Vader_Sentiment'].apply(lambda x: vader_analysis(x))
fin_data[1:50]
# Out:
#                                               Comment  \
# 1   Master of lies ....after raila impeached Uhuru...
# 2   Raila could not impeach Uhuru so that you bene...
# 3   Ruto can say anything now that his ill plans h...
# 4   Mr Promises is a dangerous kalenjinga. Can do ...
# 5   You still have my vote...all i wish is you had...
# 6   If so that would have happened in 2013-17,but ...
# 7   Kumbe ni Ukweli! But who would have constituti...
# 8   😂 Uhuru could not support Raila if not of the ...
# 9   If Roto wanted to impeach Uhuru he could overt...
# 10  this is a confirmation that Uhuru is right.Rut...
# 11  WSR had no reason to impeach Uhuru,  Uhuru imp...
# 12    God may you bless Ruto and fight for him Amen!!
# 13  This impeachment of uhuru Kenyatta was of bene...
# 14  So there was an impeachment plan 😳 received th...
# 15  AND AS HIS PRINCIPAL ASSISTANT YOU DIDN'T INFO...
# 16                      He should blame uhuru on this
# 17  So the impeachment story is True!  Now I know ...
# 18  We don't care who wanted to peanch who"Ruto al...
# 19  Hooo how did he know and what steps did he too...
# 20  Mr. Ruto, your case was more dangerous than th...
# 21  The earlier people adapt to RUTO becoming the ...
# 22  Thank God Mr Ruto ,Uhuru isn't even telling us...
# 23  Please. He didn't say that. He only said there...
# 24  And i said once, A Tragic Hero is brought down...
# 25  He should tell us what caused the fall out if ...
# 26  Head of state should be ashamed himself blamin...
# 27  So it's undeniable fact that there was impeach...
# 28  How does that consern Raila,He will gain nothi...
# 29  Raila its understood he even took an oath pret...
# 30  For what? Then you become the President? ...ho...
# 31  And who could have benefited on impeachment an...
# 32  Very true after all that raila went through,Ho...
# 33  NTV Kenya... What a pitiful headline...!! What...
# 34  We all know that the kenyaras and the mois are...
# 35  We have known also who was the killer,,Uhuru m...
# 36  Meaning their is some truth in president's all...
# 37                 Somebody inform me about saba saba
# 38     Why keep such information to date mr.sixmonths
# 39  Ruto bungled Jubilee primaries in 2017, instal...
# 40  Stop being confused, dragging Raila's  name in...
# 41  Very true the incoming prezzo he is confusing ...
# 42  Well said sir,,it was Raila who wanted uhuru K...
# 43              Confirmed! you wanted to impeach him!
# 44  Y r calling Railas name you Ruto.The president...
# 45  Livondo knows better than u,Baba hayuko kwa ha...
# 46  May be the world wld Av been better if three o...
# 47  Mr double speak you're the dp incase uhuru is ...
# 48  So impeachment plans were there? The question ...
# 49  How did ruto know that it was Raila who wanted...
#
#                                                 Lemma  Vader_Sentiment  \
# 1     Master lie .... raila impeached Uhuru benefi...           0.0516
# 2     Raila could impeach Uhuru benefit ... 're fo...           0.3875
# 3     Ruto say anything ill plan exposed .. danger...          -0.7351
# 4     Mr Promises dangerous kalenjinga . anything ...          -0.8316
# 5     still vote ... wish succeeded impeachment .....           0.2500
# 6     would happened -17 , question ? ? Yet tyrann...           0.3094
# 7     Kumbe ni Ukweli ! would constitutionally ben...           0.0000
# 8     Uhuru could support Raila hurtful betrayal M...          -0.6170
# 9     Roto wanted impeach Uhuru could overthrow ti...           0.0000
# 10           confirmation Uhuru right.Ruto ill plan .          -0.4215
# 11    WSR reason impeach Uhuru , Uhuru impeached h...          -0.5996
# 12                  God may bless Ruto fight Amen ! !           0.4374
# 13    impeachment uhuru Kenyatta benefit n't know ...          -0.2273
# 14    impeachment plan received news alot shock si...          -0.5012
# 15    PRINCIPAL ASSISTANT N'T INFORM RAILA PLANNIN...           0.0000
# 16                                        blame uhuru          -0.3400
# 17    impeachment story True ! know even Kuibia / ...           0.7088
# 18              n't care wanted peanch '' Ruto way ''          -0.3875
# 19                Hooo know step took safeguard bos ?           0.3818
# 20    Mr. Ruto , case dangerous Raila openly oppon...          -0.5984
# 21    early people adapt RUTO becoming th Presiden...          -0.5106
# 22    Thank God Mr Ruto , Uhuru n't even telling u...           0.8555
# 23    Please . n't say . said 's leader Kenya 's k...           0.3802
# 24    said , Tragic Hero brought Tragic Flaws . Ru...          -0.8070
# 25            tell us caused fall Uhuru talking truth          -0.2411
# 26    Head state ashamed blaming deputy governor w...          -0.7430
# 27    's undeniable fact impeachment . president r...           0.4215
# 28    consern Raila , gain nothing opposition lead...           0.8429
# 29    Raila understood even took oath pretending p...           0.5789
# 30    ? become President ? ... possible , Raila im...           0.0000
# 31    could benefited impeachment tell uhuru since...           0.7184
# 32    true raila went , However , get known plan ?...           0.7240
# 33    NTV Kenya ... pitiful headline ... ! ! narro...          -0.7762
# 34    know kenyaras mois working capture voter che...          -0.1779
# 35                known also killer , ,Uhuru mwenyewe           0.0000
# 36    Meaning truth president 's allegations.But t...           0.3182
# 37                          Somebody inform saba saba           0.0000
# 38                 keep information date mr.sixmonths           0.0000
# 39    Ruto bungled Jubilee primary , installed pup...           0.1280
# 40    Stop confused , dragging Raila 's name every...          -0.8674
# 41                     true incoming prezzo confusing           0.2944
# 42    Well said sir , ,it Raila wanted uhuru Kenya...          -0.2500
# 43                       Confirmed ! wanted impeach !           0.0000
# 44    r calling Railas name Ruto.The president sai...          -0.5410
# 45    Livondo knows good u , Baba hayuko kwa hasir...           0.7941
# 46     May world wld Av well three impeached ... ....           0.4404
# 47    Mr double speak 're dp incase uhuru impeache...           0.8126
# 48    impeachment plan ? question whether 's true ...          -0.4003
# 49    ruto know Raila wanted impeach UHURU informa...           0.6540
#
#    Vader_Analysis
# 1        Positive
# 2        Positive
# 3        Negative
# 4        Negative
# 5        Positive
# 6        Positive
# 7         Neutral
# 8        Negative
# 9         Neutral
# 10       Negative
# 11       Negative
# 12       Positive
# 13       Negative
# 14       Negative
# 15        Neutral
# 16       Negative
# 17       Positive
# 18       Negative
# 19       Positive
# 20       Negative
# 21       Negative
# 22       Positive
# 23       Positive
# 24       Negative
# 25       Negative
# 26       Negative
# 27       Positive
# 28       Positive
# 29       Positive
# 30        Neutral
# 31       Positive
# 32       Positive
# 33       Negative
# 34       Negative
# 35        Neutral
# 36       Positive
# 37        Neutral
# 38        Neutral
# 39       Positive
# 40       Negative
# 41       Positive
# 42       Negative
# 43        Neutral
# 44       Negative
# 45       Positive
# 46       Positive
# 47       Positive
# 48       Negative
# 49       Positive

# %%
vd_counts = fin_data["Vader_Analysis"].value_counts()
vd_counts
# Out:
# Positive    84
# Negative    73
# Neutral     71
# Name: Vader_Analysis, dtype: int64

# %% [markdown]
# ## Named Entity Recognition

# %%
nlp = spacy.load("political_ner_model")
fin_data["tags"] = df["clean_tweets"].apply(lambda x: [(tag.text, tag.label_) for tag in nlp(x).ents])
fin_data[1:50]
# Out:
#                                               Comment  \
# 1   Master of lies ....after raila impeached Uhuru...
# 2   Raila could not impeach Uhuru so that you bene...
# 3   Ruto can say anything now that his ill plans h...
# 4   Mr Promises is a dangerous kalenjinga. Can do ...
# 5   You still have my vote...all i wish is you had...
# 6   If so that would have happened in 2013-17,but ...
# 7   Kumbe ni Ukweli! But who would have constituti...
# 8   😂 Uhuru could not support Raila if not of the ...
# 9   If Roto wanted to impeach Uhuru he could overt...
# 10  this is a confirmation that Uhuru is right.Rut...
# 11  WSR had no reason to impeach Uhuru,  Uhuru imp...
# 12    God may you bless Ruto and fight for him Amen!!
# 13  This impeachment of uhuru Kenyatta was of bene...
# 14  So there was an impeachment plan 😳 received th...
# 15  AND AS HIS PRINCIPAL ASSISTANT YOU DIDN'T INFO...
# 16                      He should blame uhuru on this
# 17  So the impeachment story is True!  Now I know ...
# 18  We don't care who wanted to peanch who"Ruto al...
# 19  Hooo how did he know and what steps did he too...
# 20  Mr. Ruto, your case was more dangerous than th...
# 21  The earlier people adapt to RUTO becoming the ...
# 22  Thank God Mr Ruto ,Uhuru isn't even telling us...
# 23  Please. He didn't say that. He only said there...
# 24  And i said once, A Tragic Hero is brought down...
# 25  He should tell us what caused the fall out if ...
# 26  Head of state should be ashamed himself blamin...
# 27  So it's undeniable fact that there was impeach...
# 28  How does that consern Raila,He will gain nothi...
# 29  Raila its understood he even took an oath pret...
# 30  For what? Then you become the President? ...ho...
# 31  And who could have benefited on impeachment an...
# 32  Very true after all that raila went through,Ho...
# 33  NTV Kenya... What a pitiful headline...!! What...
# 34  We all know that the kenyaras and the mois are...
# 35  We have known also who was the killer,,Uhuru m...
# 36  Meaning their is some truth in president's all...
# 37                 Somebody inform me about saba saba
# 38     Why keep such information to date mr.sixmonths
# 39  Ruto bungled Jubilee primaries in 2017, instal...
# 40  Stop being confused, dragging Raila's  name in...
# 41  Very true the incoming prezzo he is confusing ...
# 42  Well said sir,,it was Raila who wanted uhuru K...
# 43              Confirmed! you wanted to impeach him!
# 44  Y r calling Railas name you Ruto.The president...
# 45  Livondo knows better than u,Baba hayuko kwa ha...
# 46  May be the world wld Av been better if three o...
# 47  Mr double speak you're the dp incase uhuru is ...
# 48  So impeachment plans were there? The question ...
# 49  How did ruto know that it was Raila who wanted...
#
#                                                 Lemma  Vader_Sentiment  \
# 1     Master lie .... raila impeached Uhuru benefi...           0.0516
# 2     Raila could impeach Uhuru benefit ... 're fo...           0.3875
# 3     Ruto say anything ill plan exposed .. danger...          -0.7351
# 4     Mr Promises dangerous kalenjinga . anything ...          -0.8316
# 5     still vote ... wish succeeded impeachment .....           0.2500
# 6     would happened -17 , question ? ? Yet tyrann...           0.3094
# 7     Kumbe ni Ukweli ! would constitutionally ben...           0.0000
# 8     Uhuru could support Raila hurtful betrayal M...          -0.6170
# 9     Roto wanted impeach Uhuru could overthrow ti...           0.0000
# 10           confirmation Uhuru right.Ruto ill plan .          -0.4215
# 11    WSR reason impeach Uhuru , Uhuru impeached h...          -0.5996
# 12                  God may bless Ruto fight Amen ! !           0.4374
# 13    impeachment uhuru Kenyatta benefit n't know ...          -0.2273
# 14    impeachment plan received news alot shock si...          -0.5012
# 15    PRINCIPAL ASSISTANT N'T INFORM RAILA PLANNIN...           0.0000
# 16                                        blame uhuru          -0.3400
# 17    impeachment story True ! know even Kuibia / ...           0.7088
# 18              n't care wanted peanch '' Ruto way ''          -0.3875
# 19                Hooo know step took safeguard bos ?           0.3818
# 20    Mr. Ruto , case dangerous Raila openly oppon...          -0.5984
# 21    early people adapt RUTO becoming th Presiden...          -0.5106
# 22    Thank God Mr Ruto , Uhuru n't even telling u...           0.8555
# 23    Please . n't say . said 's leader Kenya 's k...           0.3802
# 24    said , Tragic Hero brought Tragic Flaws . Ru...          -0.8070
# 25            tell us caused fall Uhuru talking truth          -0.2411
# 26    Head state ashamed blaming deputy governor w...          -0.7430
# 27    's undeniable fact impeachment . president r...           0.4215
# 28    consern Raila , gain nothing opposition lead...           0.8429
# 29    Raila understood even took oath pretending p...           0.5789
# 30    ? become President ? ... possible , Raila im...           0.0000
# 31    could benefited impeachment tell uhuru since...           0.7184
# 32    true raila went , However , get known plan ?...           0.7240
# 33    NTV Kenya ... pitiful headline ... ! ! narro...          -0.7762
# 34    know kenyaras mois working capture voter che...          -0.1779
# 35                known also killer , ,Uhuru mwenyewe           0.0000
# 36    Meaning truth president 's allegations.But t...           0.3182
# 37                          Somebody inform saba saba           0.0000
# 38                 keep information date mr.sixmonths           0.0000
# 39    Ruto bungled Jubilee primary , installed pup...           0.1280
# 40    Stop confused , dragging Raila 's name every...          -0.8674
# 41                     true incoming prezzo confusing           0.2944
# 42    Well said sir , ,it Raila wanted uhuru Kenya...          -0.2500
# 43                       Confirmed ! wanted impeach !           0.0000
# 44    r calling Railas name Ruto.The president sai...          -0.5410
# 45    Livondo knows good u , Baba hayuko kwa hasir...           0.7941
# 46     May world wld Av well three impeached ... ....           0.4404
# 47    Mr double speak 're dp incase uhuru impeache...           0.8126
# 48    impeachment plan ? question whether 's true ...          -0.4003
# 49    ruto know Raila wanted impeach UHURU informa...           0.6540
#
#    Vader_Analysis                                               tags
# 1        Positive                              [(Uhuru, POLITICIAN)]
# 2        Positive         [(Raila, POLITICIAN), (Uhuru, POLITICIAN)]
# 3        Negative                               [(Ruto, POLITICIAN)]
# 4        Negative                                                 []
# 5        Positive                              [(Uhuru, POLITICIAN)]
# 6        Positive                       [(Jubilee, POLITICAL_PARTY)]
# 7         Neutral                              [(Uhuru, POLITICIAN)]
# 8        Negative  [(Uhuru, POLITICIAN), (Raila, POLITICIAN), (Mr...
# 9         Neutral                              [(Uhuru, POLITICIAN)]
# 10       Negative          [(Uhuru, POLITICIAN), (Ruto, POLITICIAN)]
# 11       Negative  [(WSR, POLITICIAN), (Uhuru, POLITICIAN), (Uhur...
# 12       Positive                               [(Ruto, POLITICIAN)]
# 13       Negative                           [(Kenyatta, POLITICIAN)]
# 14       Negative                                                 []
# 15        Neutral                           [(AND, POLITICAL_PARTY)]
# 16       Negative                                                 []
# 17       Positive                                                 []
# 18       Negative                                                 []
# 19       Positive                                                 []
# 20       Negative  [(Mr. Ruto, POLITICAL_PARTY), (Raila, POLITICI...
# 21       Negative                                                 []
# 22       Positive          [(Ruto, POLITICIAN), (Uhuru, POLITICIAN)]
# 23       Positive                                                 []
# 24       Negative                               [(Ruto, POLITICIAN)]
# 25       Negative                              [(Uhuru, POLITICIAN)]
# 26       Negative                                                 []
# 27       Positive                                                 []
# 28       Positive        [(Raila, POLITICIAN), (Deputy, POLITICIAN)]
# 29       Positive                              [(Raila, POLITICIAN)]
# 30        Neutral          [(Raila, POLITICIAN), (Ruto, POLITICIAN)]
# 31       Positive                                                 []
# 32       Positive                                                 []
# 33       Negative                                                 []
# 34       Negative                            [(DP, POLITICAL_PARTY)]
# 35        Neutral                                                 []
# 36       Positive                            [(Meaning, POLITICIAN)]
# 37        Neutral                                                 []
# 38        Neutral                                                 []
# 39       Positive  [(Ruto, POLITICIAN), (Jubilee, POLITICAL_PARTY...
# 40       Negative         [(Raila, POLITICIAN), (Uhuru, POLITICIAN)]
# 41       Positive                                                 []
# 42       Negative      [(Raila, POLITICIAN), (Kenyatta, POLITICIAN)]
# 43        Neutral                          [(Confirmed, POLITICIAN)]
# 44       Negative                               [(Ruto, POLITICIAN)]
# 45       Positive                               [(Baba, POLITICIAN)]
# 46       Positive                                                 []
# 47       Positive                                                 []
# 48       Negative                                                 []
# 49       Positive  [(Raila, POLITICIAN), (Raila, POLITICIAN), (Ra...

# %% [markdown]
# ## Get names and political parties

# %%
fin_data["Parties"] = fin_data["tags"].apply(lambda x: get_parties(x))
fin_data["Politicians"] = fin_data["tags"].apply(lambda x: get_names(x))
fin_data[50:100]
# Out:
#                                               Comment  \
# 50  Tell us more the three of you know something,c...
# 51  2 b a Ruto supporter, ni kazi, jana, they all ...
# 52  Uhuru is so confused by now,his lies are not a...
# 53      Wish it could succeed but 9th it will succeed
# 54  People urgue as if Kenya is a Kingdom. We neve...
# 55  Uhuru you are confused, rem the time of ICC yo...
# 56  Uhuru knows it was you period other excuses ji...
# 57  Hahaha,that's my Fifth president!!!by the way ...
# 58  Shifting your burden to other people won't giv...
# 59  😛😛😛😛😛😛mmmmm. Seems there is truth in this impe...
# 60  I wonder why our 5th is responding to this per...
# 61  Which numbers do Raila had to impeach Uhuru , ...
# 62      This man is very dangerous my fellow kenyan's
# 63  These people they have nothing beneficial to d...
# 64  Yes, says His Excellency William Ruto. The fif...
# 65  Ntv another propaganda tool when did he mentio...
# 66  How many MPs Raila had in parliament? Infact v...
# 67  Who wanted to impeach who  ? Can everybody com...
# 68  What would RAO gain by impeaching Uhuru?? Ruto...
# 69  You wonder how Hon.President know all this sto...
# 70  But you would have automatically become presid...
# 71  The outgoing DP and the incoming leader of opp...
# 72  Did you inform Uhuro of the intended impeachment?
# 73  Don't be stupid, as per the constitution who b...
# 74  If raila wanted to impeach Uhuru,who will take...
# 75  Did you told your boss that there is someone w...
# 76  So you knew but didn't tell your 'good friend'...
# 77  Sugoi boy now wants to tell us Uhuru doesn't k...
# 78  In no way Raila could impeach the president be...
# 79  Why should Raila impeach Uhuru for you to be t...
# 80  WISHING POLITICAL LEADERS ALL THE BEST.👀.MAY BE!.
# 81  Raila didn't have Numbers in Parliament to imp...
# 82  By the time only 60 days remaining to election...
# 83  No...our 5th responded like this..."don't conf...
# 84  How i wish he would have been impeached with t...
# 85  Raila had no numbers that could even make him ...
# 86  So dp can clearly indicate there was a plan of...
# 87                                 With how many mps?
# 88     Whoever believes in this guys lies is also mad
# 89  No wonder even Jesus Christ was betrayed, Juda...
# 90  Ruto no need to defend yourself, We know how t...
# 91  After Raila swore himself in ,openly that show...
# 92  And who then could become the president ruto o...
# 93  All and  sundry have been demanding the presid...
# 94  Then who will become the president if the impe...
# 95  We don't care about who wanted to impeach who,...
# 96  Frm point of view Rao is a betrayer once again...
# 97      So you knew something about impeachment??! 🤔🤔
# 98  Infact we blame you coz you could have done it...
# 99  We're they playing kibe there?? That the presi...
#
#                                                 Lemma  Vader_Sentiment  \
# 50    Tell us three know something , confess waiti...           0.0000
# 51    b Ruto supporter , ni kazi , jana , agreed R...           0.4939
# 52        Uhuru confused , lie adding anymore.Ruto th          -0.6995
# 53                      Wish could succeed th succeed           0.8047
# 54    People urgue Kenya Kingdom . never learned C...           0.0000
# 55    Uhuru confused , rem time ICC give power giv...          -0.1655
# 56                  Uhuru knows period excuse jiwekee           0.0000
# 57    Hahaha , 's Fifth president ! ! ! way maybe ...           0.0000
# 58    Shifting burden people wo n't give sympathy ...          -0.6136
# 59    mmmmm . Seems truth impeachment thing ! ! co...           0.6103
# 60    wonder th responding person infact waiting d...           0.0000
# 61    number Raila impeach Uhuru , could benefit R...           0.7918
# 62                     man dangerous fellow kenyan 's          -0.5256
# 63    people nothing beneficial discuss us blaming...          -0.6814
# 64    Yes , says Excellency William Ruto . fifth p...           0.7351
# 65    Ntv another propaganda tool mention raila . ...          -0.2500
# 66    many MPs Raila parliament ? Infact , hangepa...           0.4588
# 67            wanted impeach ? everybody come clear ?           0.4515
# 68    would RAO gain impeaching Uhuru ? ? Ruto n't...           0.5803
# 69    wonder Hon.President know story , utajuwa hu...           0.0000
# 70    would automatically become president Raila O...           0.0000
# 71    outgoing DP incoming leader opposition stres...          -0.0516
# 72                inform Uhuro intended impeachment ?           0.0000
# 73    n't stupid , per constitution benefit automa...           0.6571
# 74    raila wanted impeach Uhuru , take mantle , g...           0.0000
# 75    told bos someone want impeach ? step took st...           0.2406
# 76         knew n't tell 'good friend ' ? Hypocrisy !           0.3576
# 77    Sugoi boy wants tell us Uhuru n't know diffe...           0.0000
# 78    way Raila could impeach president number Par...          -0.5267
# 79                    Raila impeach Uhuru president ?           0.0000
# 80          WISHING POLITICAL LEADERS BEST .. MAY ! .           0.8342
# 81    Raila n't Numbers Parliament impeach Preside...          -0.2500
# 82    time day remaining election wewe sijui utawe...          -0.8860
# 83    ... th responded like ... '' n't confuse eld...           0.9708
# 84                   wish would impeached price thing           0.4019
# 85    Raila number could even make think impeachin...          -0.2960
# 86    dp clearly indicate plan impeachment whateve...           0.4522
# 87                                          many mp ?           0.0000
# 88                 Whoever believes guy lies also mad          -0.7184
# 89    wonder even Jesus Christ betrayed , Judas n'...          -0.4685
# 90    Ruto need defend , know play Chess UHURU poo...          -0.3612
# 91    Raila swore , openly shows wanted remove uhu...          -0.4767
# 92                could become president ruto raila ?           0.0000
# 93    sundry demanding president come explain happ...          -0.4215
# 94    become president impeachment succeed ? huyu ...           0.0000
# 95                 n't care wanted impeach , Raila th          -0.3875
# 96    Frm point view Rao betrayer planned even swe...          -0.8577
# 97                   knew something impeachment ? ? !           0.0000
# 98    Infact blame coz could done , regretting coz...          -0.8176
# 99     're playing kibe ? ? president ca n't tell ? ?           0.4137
#
#    Vader_Analysis                                               tags Parties  \
# 50        Neutral                                                 []    None
# 51       Positive  [(Ruto, POLITICIAN), (Ruto, POLITICIAN), (Uhur...    None
# 52       Negative          [(Uhuru, POLITICIAN), (Ruto, POLITICIAN)]    None
# 53       Positive                                                 []    None
# 54        Neutral                                                 []    None
# 55       Negative                              [(Uhuru, POLITICIAN)]    None
# 56        Neutral                              [(Uhuru, POLITICIAN)]    None
# 57        Neutral                              [(Raila, POLITICIAN)]    None
# 58       Negative                                                 []    None
# 59       Positive         [(Raila, POLITICIAN), (Uhuru, POLITICIAN)]    None
# 60        Neutral                                                 []    None
# 61       Positive  [(Raila, POLITICIAN), (Uhuru, POLITICIAN), (Ra...    None
# 62       Negative                                                 []    None
# 63       Negative                              [(These, POLITICIAN)]    None
# 64       Positive        [(William, POLITICIAN), (Ruto, POLITICIAN)]    None
# 65       Negative                                                 []    None
# 66       Positive                              [(Raila, POLITICIAN)]    None
# 67       Positive                                                 []    None
# 68       Positive  [(Uhuru, POLITICIAN), (Ruto, POLITICIAN), (Uhu...    None
# 69        Neutral                                                 []    None
# 70        Neutral        [(Raila, POLITICIAN), (Odinga, POLITICIAN)]    None
# 71       Negative                                 [(DP, POLITICIAN)]    None
# 72        Neutral                                                 []    None
# 73       Positive                             [(Deputy, POLITICIAN)]    None
# 74        Neutral                              [(Uhuru, POLITICIAN)]    None
# 75       Positive                                                 []    None
# 76       Positive                                                 []    None
# 77        Neutral  [(Uhuru, POLITICIAN), (Ruto, POLITICIAN), (Rai...    None
# 78       Negative          [(Raila, POLITICIAN), (Ruto, POLITICIAN)]    None
# 79        Neutral         [(Raila, POLITICIAN), (Uhuru, POLITICIAN)]    None
# 80       Positive                           [(THE, POLITICAL_PARTY)]   [THE]
# 81       Negative  [(Raila, POLITICIAN), (Baba, POLITICIAN), (Rai...    None
# 82       Negative                                                 []    None
# 83       Positive                                                 []    None
# 84       Positive                                                 []    None
# 85       Negative         [(Raila, POLITICIAN), (Uhuru, POLITICIAN)]    None
# 86       Positive                                                 []    None
# 87        Neutral                                                 []    None
# 88       Negative                                                 []    None
# 89       Negative                              [(Judas, POLITICIAN)]    None
# 90       Negative                               [(Ruto, POLITICIAN)]    None
# 91       Negative      [(Raila, POLITICIAN), (Kenyatta, POLITICIAN)]    None
# 92        Neutral                                                 []    None
# 93       Negative                               [(Baba, POLITICIAN)]    None
# 94        Neutral                                                 []    None
# 95       Negative                              [(Raila, POLITICIAN)]    None
# 96       Negative           [(Rao, POLITICIAN), (Uhuru, POLITICIAN)]    None
# 97        Neutral                                                 []    None
# 98       Negative                                                 []    None
# 99       Positive                                                 []    None
#
#                          Politicians
# 50                                []
# 51              [Ruto, Uhuru, Raila]
# 52                     [Uhuru, Ruto]
# 53                                []
# 54                                []
# 55                           [Uhuru]
# 56                           [Uhuru]
# 57                           [Raila]
# 58                                []
# 59                    [Raila, Uhuru]
# 60                                []
# 61               [Raila, Uhuru, Mr.]
# 62                                []
# 63                           [These]
# 64                   [William, Ruto]
# 65                                []
# 66                           [Raila]
# 67                                []
# 68                     [Uhuru, Ruto]
# 69                                []
# 70                   [Raila, Odinga]
# 71                              [DP]
# 72                                []
# 73                          [Deputy]
# 74                           [Uhuru]
# 75                                []
# 76                                []
# 77              [Uhuru, Ruto, Raila]
# 78                     [Raila, Ruto]
# 79                    [Raila, Uhuru]
# 80                                []
# 81  [Raila, Baba, Uhuru, Ruto, Boss]
# 82                                []
# 83                                []
# 84                                []
# 85                    [Raila, Uhuru]
# 86                                []
# 87                                []
# 88                                []
# 89                           [Judas]
# 90                            [Ruto]
# 91                 [Raila, Kenyatta]
# 92                                []
# 93                            [Baba]
# 94                                []
# 95                           [Raila]
# 96                      [Rao, Uhuru]
# 97                                []
# 98                                []
# 99                                []

# %% [markdown]
# # Project to predict the popularity of Political leaders and detect hate speech and tribalism from Facebook and Twitter comments

# %% [markdown]
# ## Imports

# %%
from webdriver_manager.chrome import ChromeDriverManager

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

from bs4 import BeautifulSoup

import pandas as pd

import time

# for tweets collection
import tweepy

# text cleaning
import preprocessor as p

# text preprocessing
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.corpus import wordnet

#lemmatization
from nltk.stem import WordNetLemmatizer

#sentiment analysis
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk.tag import pos_tag

## visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# get the language of the text
import langdetect
#for ner recognition
import spacy

from langdetect.lang_detect_exception import LangDetectException

# %% [markdown]
# # GET FACEBOOK COMMENTS

# %%
# scroll down
def scroll():
    pop_out_btn = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.ID, "popup_xout")))
    pop_out_btn.click()

# %%
# funtion to click the view more button
def view_more_click(driver):
    try: 
        view_more_comments = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.LINK_TEXT, "View more comments…")))
        view_more_comments.click()
    
    except TimeoutException:
        view_more_comments = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.LINK_TEXT, "View previous comments…")))
        view_more_comments.click()
        
    except ElementClickInterceptedException:
        scroll()
    
    except (NoSuchElementException,ElementClickInterceptedException, StaleElementReferenceException) as es :
        print(es)
    html = driver.page_source
    return html

# function to click the button 50 times
def view_more_comm(driver):
    i = 0
    while i < 50:
        html = view_more_click(driver)
        time.sleep(3)
        i += 1
    return html

# %%
# function to get a list of all the comment elements
def get_comments(html):
    soup = BeautifulSoup(html, 'html.parser')
    comment_section = soup.find("div", {"class":"_59e9 _1-ut _2a_g _34oh" })
    comment_els = comment_section.find_all("div", {"class":"_2a_i"})
    
    master_list = []
    for c in comment_els:
        data_dict = {}
        data_dict["User"] = c.find("div", {"class":"_2b05"}).text
        data_dict["Comment"] = c.find("div", {"data-sigil":"comment-body"}).text
        master_list.append(data_dict)
    return master_list

# %% [markdown]
# # GETTING TWITTER DATA

# %% [markdown]
# ## Twitter Authentication

# %%
# read the keys from the file 
def authorize_twitter():
    keys = []
    with open('../Keys.txt') as f:
        for line in f:
            keys.append(line.strip())

    API_KEY = keys[1]
    API_KEY_SECRET = keys [4]
    ACCESS_TOKEN = keys[10]
    ACCESS_TOKEN_SECRET = keys[13]
    
    # initialize the api
    auth = tweepy.OAuthHandler(API_KEY, API_KEY_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
    api = tweepy.API(auth)
    
    return (api)

# %% [markdown]
# ## Get the replies from the posts

# %%
def get_replies(url):
    name = url.split("/")[-3]
    tweet_id = url.split("/")[-1]

    #empty list for the replies
    replies = []
    
    api = authorize_twitter()
    # get replies from the tweet
    for tweet in tweepy.Cursor(api.search_tweets,q='to:'+name, result_type='recent').items(1000):
        if hasattr(tweet, 'in_reply_to_status_id_str'):
            if (tweet.in_reply_to_status_id_str==tweet_id):
                replies.append(tweet)
    
    #master list to hold all the data needed
    master_list = []
    for reply in replies:
        data_dict = {}
        data_dict["User"] = reply.author.screen_name
        data_dict["Comment"] = reply.text

        master_list.append(data_dict)
        
    return (master_list)

# %% [markdown]
# # TEXT PREPROCESSING

# %% [markdown]
# ## Tokenization and POS tagging + removing stop words

# %%
#perform tokenization and pos tagging and remove stop words
pos_dict = {'J': wordnet.ADJ, 'v': wordnet.VERB, 'N': wordnet.NOUN, 'R': wordnet.ADV}
def token_stop_pos(text):
    tags = pos_tag(word_tokenize(text))
    newlist = []
    
    for word, tag in tags:
        if word.lower() not in set(stopwords.words('english')):
            newlist.append(tuple([word, pos_dict.get(tag[0])]))
            
    return newlist

# %% [markdown]
# ## Lemmatization

# %%
wordnet_lemmatizer = WordNetLemmatizer()
def lemmatize(pos_data):
    lemma_rew = " "
    for word, pos in pos_data:
        if not pos:
            lemma = word
            lemma_rew = lemma_rew + " " + lemma
        else:
            lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
            lemma_rew = lemma_rew + " " + lemma
    return lemma_rew

# %% [markdown]
# ## Language detection

# %%
def get_language(text):
    try:
        lang = langdetect.detect(text)
        
        return lang
    except LangDetectException:
        print(text, "is invalid")

# %% [markdown]
# ## SENTIMENT ANALYSIS USING VADER

# %%
def vaderSentimentAnalysis(text):
    analyzer = SentimentIntensityAnalyzer()
    vs= analyzer.polarity_scores(text)
    return vs['compound']

# function to analyse 
def vader_analysis(compound):
    if compound > 0:
        return 'Positive'
    elif compound < 0 :
        return 'Negative'
    else:
        return 'Neutral'

# %% [markdown]
# ## Get names and parties from the text

# %%
def get_parties(text):
    for i in range(len(text)):
        parties=[]
        tags = text[i][1]
        if tags == "POLITICAL_PARTY":
            party = text[i][0]
            if party not in parties:
                parties.append(party)
        else:
            continue
        return parties

# %%
def get_names(text):
    names=[]
    for i in range(len(text)):
        tags = text[i][1]
        if tags == "POLITICIAN":
            name = text[i][0]
            if name not in names:
                names.append(name)
        else:
            continue
    return names

# %% [markdown]
# # MAIN FILE

# %%
choice = input("Please select the choice of your data. \n 1. for facebook. \n 2. For twitter")
if choice == "1":
    # install webdriver
    driver = webdriver.Chrome(ChromeDriverManager().install())
    url = input("Paste the Facebook mobile url: ")
    driver.get(url)

    print("Getting comments please wait...\n")
    html = view_more_comm(driver)

    master_list = get_comments(html)

    print(str(len(master_list)) + " Comments found")
        
else:
    url = input("Paste the tweet url: ")
    print("----Getting replies please wait------")
    master_list = get_replies(url)
    print(str(len(master_list)) + " Comments found")
# Out:
# Please select the choice of your data.
#  1. for facebook.
#  2. For twitter1
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [C:\Users\NYAM\.wdm\drivers\chromedriver\win32\99.0.4844.51\chromedriver.exe] found in cache
# C:\Users\NYAM\AppData\Local\Temp/ipykernel_11384/3174541939.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# Paste the Facebook mobile url: https://mobile.facebook.com/story.php?story_fbid=10160054567584430&id=88201339429&m_entstream_source=timeline
# Getting comments please wait...
#
# 1274 Comments found

# %%
    #create a dataframe and clean the text
df = pd.DataFrame(master_list)
df["clean_tweets"] = df["Comment"].apply(lambda x: p.clean(x))
df
# Out:
#                             User  \
# 0             Jibril Iron Shaffi
# 1     Fieldmarshal Newton Mwaura
# 2                   Khalif Kairo
# 3                 Grace Waithira
# 4                Mutaih Vinneous
# ...                          ...
# 1269            Alex Yang Muembu
# 1270             Sambula De King
# 1271             Okemwa Anderson
# 1272                  Kago Mburu
# 1273                 Edgar Orlov
#
#                                                 Comment  \
# 0     It must be a special helicopter just like the ...
# 1     Tell that to the birds, very ignorant post and...
# 2     Media loves overblowing stuff😅 Blades pekee fo...
# 3     Insurance does not pay for Campaign incidents,...
# 4     Si waliiba condoms pale KEMSA. Wauze na watumi...
# ...                                                 ...
# 1269            Stephen Mukangai can do it at 20k..🏃✊🇰🇪
# 1270                              Kaka Wilfred 😁😁😁😁 ...
# 1271  Dorothy Makabe I will surprise you with the co...
# 1272                            Mbuguss Mwalimu kapisaa
# 1273                Tonya Milton Omokamba boss surely!!
#
#                                            clean_tweets
# 0     It must be a special helicopter just like the ...
# 1     Tell that to the birds, very ignorant post and...
# 2     Media loves overblowing stuff Blades pekee for...
# 3     Insurance does not pay for Campaign incidents,...
# 4     Si waliiba condoms pale KEMSA. Wauze na watumi...
# ...                                                 ...
# 1269                  Stephen Mukangai can do it at k..
# 1270                                   Kaka Wilfred ...
# 1271  Dorothy Makabe I will surprise you with the co...
# 1272                            Mbuguss Mwalimu kapisaa
# 1273                Tonya Milton Omokamba boss surely!!
#
# [1274 rows x 3 columns]

# %% [markdown]
# ## Text Preprocessing

# %%
df['POS tagged'] = df['clean_tweets'].apply(lambda x: token_stop_pos(x))
df
# Out:
#                             User  \
# 0             Jibril Iron Shaffi
# 1     Fieldmarshal Newton Mwaura
# 2                   Khalif Kairo
# 3                 Grace Waithira
# 4                Mutaih Vinneous
# ...                          ...
# 1269            Alex Yang Muembu
# 1270             Sambula De King
# 1271             Okemwa Anderson
# 1272                  Kago Mburu
# 1273                 Edgar Orlov
#
#                                                 Comment  \
# 0     It must be a special helicopter just like the ...
# 1     Tell that to the birds, very ignorant post and...
# 2     Media loves overblowing stuff😅 Blades pekee fo...
# 3     Insurance does not pay for Campaign incidents,...
# 4     Si waliiba condoms pale KEMSA. Wauze na watumi...
# ...                                                 ...
# 1269            Stephen Mukangai can do it at 20k..🏃✊🇰🇪
# 1270                              Kaka Wilfred 😁😁😁😁 ...
# 1271  Dorothy Makabe I will surprise you with the co...
# 1272                            Mbuguss Mwalimu kapisaa
# 1273                Tonya Milton Omokamba boss surely!!
#
#                                            clean_tweets  \
# 0     It must be a special helicopter just like the ...
# 1     Tell that to the birds, very ignorant post and...
# 2     Media loves overblowing stuff Blades pekee for...
# 3     Insurance does not pay for Campaign incidents,...
# 4     Si waliiba condoms pale KEMSA. Wauze na watumi...
# ...                                                 ...
# 1269                  Stephen Mukangai can do it at k..
# 1270                                   Kaka Wilfred ...
# 1271  Dorothy Makabe I will surprise you with the co...
# 1272                            Mbuguss Mwalimu kapisaa
# 1273                Tonya Milton Omokamba boss surely!!
#
#                                              POS tagged
# 0     [(must, None), (special, a), (helicopter, n), ...
# 1     [(Tell, None), (birds, n), (,, None), (ignoran...
# 2     [(Media, n), (loves, None), (overblowing, None...
# 3     [(Insurance, n), (pay, None), (Campaign, n), (...
# 4     [(Si, n), (waliiba, n), (condoms, n), (pale, a...
# ...                                                 ...
# 1269     [(Stephen, n), (Mukangai, n), (k, n), (.., n)]
# 1270          [(Kaka, n), (Wilfred, None), (..., None)]
# 1271  [(Dorothy, n), (Makabe, n), (surprise, None), ...
# 1272         [(Mbuguss, n), (Mwalimu, n), (kapisaa, n)]
# 1273  [(Tonya, n), (Milton, n), (Omokamba, n), (boss...
#
# [1274 rows x 4 columns]

# %%
# Lemmatization
df['Lemma'] = df['POS tagged'].apply(lambda x: lemmatize(x))
df.head()
# Out:
#                          User  \
# 0          Jibril Iron Shaffi
# 1  Fieldmarshal Newton Mwaura
# 2                Khalif Kairo
# 3              Grace Waithira
# 4             Mutaih Vinneous
#
#                                              Comment  \
# 0  It must be a special helicopter just like the ...
# 1  Tell that to the birds, very ignorant post and...
# 2  Media loves overblowing stuff😅 Blades pekee fo...
# 3  Insurance does not pay for Campaign incidents,...
# 4  Si waliiba condoms pale KEMSA. Wauze na watumi...
#
#                                         clean_tweets  \
# 0  It must be a special helicopter just like the ...
# 1  Tell that to the birds, very ignorant post and...
# 2  Media loves overblowing stuff Blades pekee for...
# 3  Insurance does not pay for Campaign incidents,...
# 4  Si waliiba condoms pale KEMSA. Wauze na watumi...
#
#                                           POS tagged  \
# 0  [(must, None), (special, a), (helicopter, n), ...
# 1  [(Tell, None), (birds, n), (,, None), (ignoran...
# 2  [(Media, n), (loves, None), (overblowing, None...
# 3  [(Insurance, n), (pay, None), (Campaign, n), (...
# 4  [(Si, n), (waliiba, n), (condoms, n), (pale, a...
#
#                                                Lemma
# 0    must special helicopter like standard gauge ...
# 1        Tell bird , ignorant post costing narrative
# 2    Media loves overblowing stuff Blades pekee c...
# 3    Insurance pay Campaign incident , , Stone th...
# 4    Si waliiba condom pale KEMSA . Wauze na watu...

# %% [markdown]
# ## Get only english text

# %%
df['language'] = df['clean_tweets'].apply(lambda x: get_language(x) if x.strip()!="" else "")
df = df[df['language']=='en'].reset_index(drop=True)
df.drop('language', axis=1)
df
# Out:
#                            User  \
# 0            Jibril Iron Shaffi
# 1    Fieldmarshal Newton Mwaura
# 2                  Khalif Kairo
# 3                Grace Waithira
# 4                  Richie Nzeki
# ..                          ...
# 614                    Ôsmân KE
# 615             Kiprono Ruthson
# 616           Nyongo Mkalia Ini
# 617             Richard Muthoni
# 618             Okemwa Anderson
#
#                                                Comment  \
# 0    It must be a special helicopter just like the ...
# 1    Tell that to the birds, very ignorant post and...
# 2    Media loves overblowing stuff😅 Blades pekee fo...
# 3    Insurance does not pay for Campaign incidents,...
# 4    Arrest those who threw stones, present them in...
# ..                                                 ...
# 614  I can do the repairs at 5 million. Inbox assap...
# 615  BBI stipends and allowance irudi kwa economy, ...
# 616  I repair broken helicopter windscreens at nego...
# 617  Let them Consort me I will fix it at a very co...
# 618  Dorothy Makabe I will surprise you with the co...
#
#                                           clean_tweets  \
# 0    It must be a special helicopter just like the ...
# 1    Tell that to the birds, very ignorant post and...
# 2    Media loves overblowing stuff Blades pekee for...
# 3    Insurance does not pay for Campaign incidents,...
# 4    Arrest those who threw stones, present them in...
# ..                                                 ...
# 614    I can do the repairs at million. Inbox assap ..
# 615  BBI stipends and allowance irudi kwa economy, ...
# 616  I repair broken helicopter windscreens at nego...
# 617  Let them Consort me I will fix it at a very co...
# 618  Dorothy Makabe I will surprise you with the co...
#
#                                             POS tagged  \
# 0    [(must, None), (special, a), (helicopter, n), ...
# 1    [(Tell, None), (birds, n), (,, None), (ignoran...
# 2    [(Media, n), (loves, None), (overblowing, None...
# 3    [(Insurance, n), (pay, None), (Campaign, n), (...
# 4    [(Arrest, n), (threw, None), (stones, n), (,, ...
# ..                                                 ...
# 614  [(repairs, n), (million, None), (., None), (In...
# 615  [(BBI, n), (stipends, n), (allowance, n), (iru...
# 616  [(repair, None), (broken, a), (helicopter, n),...
# 617  [(Let, None), (Consort, None), (fix, None), (c...
# 618  [(Dorothy, n), (Makabe, n), (surprise, None), ...
#
#                                                  Lemma language
# 0      must special helicopter like standard gauge ...       en
# 1          Tell bird , ignorant post costing narrative       en
# 2      Media loves overblowing stuff Blades pekee c...       en
# 3      Insurance pay Campaign incident , , Stone th...       en
# 4      Arrest threw stone , present court , pay cos...       en
# ..                                                 ...      ...
# 614                    repair million . Inbox assap ..       en
# 615    BBI stipend allowance irudi kwa economy , wi...       en
# 616    repair broken helicopter windscreen negotiab...       en
# 617    Let Consort fix considerable friendly price ...       en
# 618    Dorothy Makabe surprise cost new helicopter ...       en
#
# [619 rows x 6 columns]

# %% [markdown]
# ## Geta clean dataframe for text analysis

# %%
fin_data= pd.DataFrame(df[['Comment', 'Lemma']])

# %% [markdown]
# ## Sentiment Analysis

# %%
fin_data['Vader_Sentiment'] = fin_data['Comment'].apply(lambda x: vaderSentimentAnalysis(x))
fin_data['Vader_Analysis'] = fin_data['Vader_Sentiment'].apply(lambda x: vader_analysis(x))
fin_data[1:50]
# Out:
#                                               Comment  \
# 1   Tell that to the birds, very ignorant post and...
# 2   Media loves overblowing stuff😅 Blades pekee fo...
# 3   Insurance does not pay for Campaign incidents,...
# 4   Arrest those who threw stones, present them in...
# 5   How now, and the windscreen wasn't even armoured?
# 6   If the insurance company is refusing to pay, t...
# 7   Most of these insurance companies  are fake. T...
# 8   The INSURANCE company were refusing to PAY for...
# 9   Actually it's more costly to repair V8 bullet ...
# 10  They should withdraw a bit of the KEMSA money ...
# 11  They now feel the pain and they never felt the...
# 12  I'm not an aircraft technician but I trust my ...
# 13  Na wenye walifanya Ivo was released with 50shi...
# 14  I dont support violence at all but i think ins...
# 15  One helicopter is about 50 serious cars costin...
# 16  Those hooligans should pay for the cost to tea...
# 17  That should not be an issue think of  improvin...
# 18  While we condemn this act of foolishness, plea...
# 19  Kina Sudi are responsible for the damage. They...
# 20  Insurances  company should investigate  this i...
# 21  hope helicopter has a CCTV let them replay and...
# 22  To what end will this helicopter story be used...
# 23  The cost shouldn't be the issue because it can...
# 24  Why are we so concentrating on such ,as a nati...
# 25            The cost of violence is extremely high.
# 26  True bro prices of essential commodities has d...
# 27  Stage managed.....which stone and what amount ...
# 28  Insurance may repair it but those culprits can...
# 29                                      It is insured
# 30  Those rowdy zombies should be ashamed by havin...
# 31      Nothing compared to KEMSA billions they stole
# 32                It can be disposed as scrap as well
# 33  That's too little. Let Uhuru reduce his Sh 2bn...
# 34  This act has truly displayed how Kenyan media ...
# 35  Let those arrested 14 gentlemen pay for replac...
# 36                                 Was it not insured
# 37  The owner of the chopper is very stingy, atlea...
# 38  While those who did the unthinkable, feel like...
# 39                  Thats small money to those guys..
# 40  Did you report the cost of repairing the sever...
# 41  Already the temporary fuel shortage has sorted...
# 42  Ksh 10 million is so small amount as vis-a-vis...
# 43  Surprising, Odm is based on a foundation of vi...
# 44  Uhuru atachota from public coffers and pay for...
# 45  The cost of hiring a choppers is enough to rep...
# 46  What was the cost of destruction cost by the r...
# 47  Kwan haina insurance? if you can afford the wh...
# 48                         Our tax found another work
# 49             Let them use the money they've stolen.
#
#                                                 Lemma  Vader_Sentiment  \
# 1         Tell bird , ignorant post costing narrative          -0.3384
# 2     Media loves overblowing stuff Blades pekee c...           0.7351
# 3     Insurance pay Campaign incident , , Stone th...          -0.6254
# 4     Arrest threw stone , present court , pay cos...          -0.8271
# 5                    , windscreen n't even armoured ?           0.0000
# 6       insurance company refusing pay , deep state .          -0.4767
# 7     insurance company fake . even belong fellows...          -0.4767
# 8     INSURANCE company refusing PAY replacement s...          -0.6560
# 9     Actually 's costly repair V8 bullet proof wi...           0.2040
# 10    withdraw bit KEMSA money stole handle minor ...          -0.7096
# 11    feel pain never felt pain used million could...          -0.1526
# 12    'm aircraft technician trust instinct inform...           0.6652
# 13           Na wenye walifanya Ivo released shilling           0.0000
# 14    dont support violence think insurance covers...           0.1326
# 15    One helicopter serious car costing m. one in...          -0.0772
# 16                   hooligan pay cost teach lesson .          -0.3612
# 17    issue think improving high standard living e...           0.6083
# 18    condemn act foolishness , please motorist en...          -0.3400
# 19    Kina Sudi responsible damage . judged causin...          -0.8481
# 20    Insurances company investigate incident hono...           0.4767
# 21    hope helicopter CCTV let replay soom threw s...           0.4404
# 22    end helicopter story used political gain ? v...          -0.6072
# 23    cost n't issue replaced peace congestion tol...           0.8201
# 24    concentrating , nation serious issue affecti...          -0.3818
# 25                     cost violence extremely high .          -0.6249
# 26    True bro price essential commodity doubled l...           0.4215
# 27    Stage managed ..... stone amount force would...          -0.4939
# 28    Insurance may repair culprit ca n't go Scotl...          -0.5920
# 29                                            insured           0.0000
# 30    rowdy zombie ashamed photo paraded social me...          -0.4767
# 31               Nothing compared KEMSA billion stole           0.0000
# 32                                disposed scrap well           0.2732
# 33    's little . Let Uhuru reduce Sh bn loss per ...          -0.3182
# 34    act truly displayed Kenyan medium house hypo...           0.4926
# 35    Let arrested gentleman pay replacement . Bob...          -0.5423
# 36                                            insured           0.0000
# 37    owner chopper stingy , atleast mechanic bite...          -0.4391
# 38        unthinkable , feel like achieved . Shameful          -0.1779
# 39                           Thats small money guy ..           0.0000
# 40    report cost repairing several vehicle damage...          -0.4404
# 41             Already temporary fuel shortage sorted          -0.2500
# 42    Ksh million small amount vis-a-vis large amo...           0.0734
# 43    Surprising , Odm based foundation violence ....          -0.4588
# 44                   Uhuru atachota public coffer pay          -0.1027
# 45                  cost hiring chopper enough repair           0.0000
# 46    cost destruction cost rowdy youth kondele DP...          -0.5719
# 47    Kwan haina insurance ? afford whole helicopt...           0.0000
# 48                             tax found another work           0.0000
# 49                         Let use money 've stolen .          -0.4939
#
#    Vader_Analysis
# 1        Negative
# 2        Positive
# 3        Negative
# 4        Negative
# 5         Neutral
# 6        Negative
# 7        Negative
# 8        Negative
# 9        Positive
# 10       Negative
# 11       Negative
# 12       Positive
# 13        Neutral
# 14       Positive
# 15       Negative
# 16       Negative
# 17       Positive
# 18       Negative
# 19       Negative
# 20       Positive
# 21       Positive
# 22       Negative
# 23       Positive
# 24       Negative
# 25       Negative
# 26       Positive
# 27       Negative
# 28       Negative
# 29        Neutral
# 30       Negative
# 31        Neutral
# 32       Positive
# 33       Negative
# 34       Positive
# 35       Negative
# 36        Neutral
# 37       Negative
# 38       Negative
# 39        Neutral
# 40       Negative
# 41       Negative
# 42       Positive
# 43       Negative
# 44       Negative
# 45        Neutral
# 46       Negative
# 47        Neutral
# 48        Neutral
# 49       Negative

# %%
vd_counts = fin_data["Vader_Analysis"].value_counts()
vd_counts
# Out:
# Neutral     285
# Negative    185
# Positive    149
# Name: Vader_Analysis, dtype: int64

# %% [markdown]
# ## Named Entity Recognition

# %%
nlp = spacy.load("political_ner_model")
fin_data["tags"] = df["clean_tweets"].apply(lambda x: [(tag.text, tag.label_) for tag in nlp(x).ents])
fin_data[1:50]
# Out:
#                                               Comment  \
# 1   Tell that to the birds, very ignorant post and...
# 2   Media loves overblowing stuff😅 Blades pekee fo...
# 3   Insurance does not pay for Campaign incidents,...
# 4   Arrest those who threw stones, present them in...
# 5   How now, and the windscreen wasn't even armoured?
# 6   If the insurance company is refusing to pay, t...
# 7   Most of these insurance companies  are fake. T...
# 8   The INSURANCE company were refusing to PAY for...
# 9   Actually it's more costly to repair V8 bullet ...
# 10  They should withdraw a bit of the KEMSA money ...
# 11  They now feel the pain and they never felt the...
# 12  I'm not an aircraft technician but I trust my ...
# 13  Na wenye walifanya Ivo was released with 50shi...
# 14  I dont support violence at all but i think ins...
# 15  One helicopter is about 50 serious cars costin...
# 16  Those hooligans should pay for the cost to tea...
# 17  That should not be an issue think of  improvin...
# 18  While we condemn this act of foolishness, plea...
# 19  Kina Sudi are responsible for the damage. They...
# 20  Insurances  company should investigate  this i...
# 21  hope helicopter has a CCTV let them replay and...
# 22  To what end will this helicopter story be used...
# 23  The cost shouldn't be the issue because it can...
# 24  Why are we so concentrating on such ,as a nati...
# 25            The cost of violence is extremely high.
# 26  True bro prices of essential commodities has d...
# 27  Stage managed.....which stone and what amount ...
# 28  Insurance may repair it but those culprits can...
# 29                                      It is insured
# 30  Those rowdy zombies should be ashamed by havin...
# 31      Nothing compared to KEMSA billions they stole
# 32                It can be disposed as scrap as well
# 33  That's too little. Let Uhuru reduce his Sh 2bn...
# 34  This act has truly displayed how Kenyan media ...
# 35  Let those arrested 14 gentlemen pay for replac...
# 36                                 Was it not insured
# 37  The owner of the chopper is very stingy, atlea...
# 38  While those who did the unthinkable, feel like...
# 39                  Thats small money to those guys..
# 40  Did you report the cost of repairing the sever...
# 41  Already the temporary fuel shortage has sorted...
# 42  Ksh 10 million is so small amount as vis-a-vis...
# 43  Surprising, Odm is based on a foundation of vi...
# 44  Uhuru atachota from public coffers and pay for...
# 45  The cost of hiring a choppers is enough to rep...
# 46  What was the cost of destruction cost by the r...
# 47  Kwan haina insurance? if you can afford the wh...
# 48                         Our tax found another work
# 49             Let them use the money they've stolen.
#
#                                                 Lemma  Vader_Sentiment  \
# 1         Tell bird , ignorant post costing narrative          -0.3384
# 2     Media loves overblowing stuff Blades pekee c...           0.7351
# 3     Insurance pay Campaign incident , , Stone th...          -0.6254
# 4     Arrest threw stone , present court , pay cos...          -0.8271
# 5                    , windscreen n't even armoured ?           0.0000
# 6       insurance company refusing pay , deep state .          -0.4767
# 7     insurance company fake . even belong fellows...          -0.4767
# 8     INSURANCE company refusing PAY replacement s...          -0.6560
# 9     Actually 's costly repair V8 bullet proof wi...           0.2040
# 10    withdraw bit KEMSA money stole handle minor ...          -0.7096
# 11    feel pain never felt pain used million could...          -0.1526
# 12    'm aircraft technician trust instinct inform...           0.6652
# 13           Na wenye walifanya Ivo released shilling           0.0000
# 14    dont support violence think insurance covers...           0.1326
# 15    One helicopter serious car costing m. one in...          -0.0772
# 16                   hooligan pay cost teach lesson .          -0.3612
# 17    issue think improving high standard living e...           0.6083
# 18    condemn act foolishness , please motorist en...          -0.3400
# 19    Kina Sudi responsible damage . judged causin...          -0.8481
# 20    Insurances company investigate incident hono...           0.4767
# 21    hope helicopter CCTV let replay soom threw s...           0.4404
# 22    end helicopter story used political gain ? v...          -0.6072
# 23    cost n't issue replaced peace congestion tol...           0.8201
# 24    concentrating , nation serious issue affecti...          -0.3818
# 25                     cost violence extremely high .          -0.6249
# 26    True bro price essential commodity doubled l...           0.4215
# 27    Stage managed ..... stone amount force would...          -0.4939
# 28    Insurance may repair culprit ca n't go Scotl...          -0.5920
# 29                                            insured           0.0000
# 30    rowdy zombie ashamed photo paraded social me...          -0.4767
# 31               Nothing compared KEMSA billion stole           0.0000
# 32                                disposed scrap well           0.2732
# 33    's little . Let Uhuru reduce Sh bn loss per ...          -0.3182
# 34    act truly displayed Kenyan medium house hypo...           0.4926
# 35    Let arrested gentleman pay replacement . Bob...          -0.5423
# 36                                            insured           0.0000
# 37    owner chopper stingy , atleast mechanic bite...          -0.4391
# 38        unthinkable , feel like achieved . Shameful          -0.1779
# 39                           Thats small money guy ..           0.0000
# 40    report cost repairing several vehicle damage...          -0.4404
# 41             Already temporary fuel shortage sorted          -0.2500
# 42    Ksh million small amount vis-a-vis large amo...           0.0734
# 43    Surprising , Odm based foundation violence ....          -0.4588
# 44                   Uhuru atachota public coffer pay          -0.1027
# 45                  cost hiring chopper enough repair           0.0000
# 46    cost destruction cost rowdy youth kondele DP...          -0.5719
# 47    Kwan haina insurance ? afford whole helicopt...           0.0000
# 48                             tax found another work           0.0000
# 49                         Let use money 've stolen .          -0.4939
#
#    Vader_Analysis                                              tags
# 1        Negative                                                []
# 2        Positive                            [(Blades, POLITICIAN)]
# 3        Negative  [(UDA, POLITICAL_PARTY), (Maintain, POLITICIAN)]
# 4        Negative                       [(Arrest, POLITICAL_PARTY)]
# 5         Neutral                                                []
# 6        Negative                                                []
# 7        Negative                                                []
# 8        Negative                                                []
# 9        Positive                               [(WSR, POLITICIAN)]
# 10       Negative                                                []
# 11       Negative                                                []
# 12       Positive                                                []
# 13        Neutral                                                []
# 14       Positive                                                []
# 15       Negative                                                []
# 16       Negative                                                []
# 17       Positive                                                []
# 18       Negative                                                []
# 19       Negative                                                []
# 20       Positive                                                []
# 21       Positive                                                []
# 22       Negative                                                []
# 23       Positive                                                []
# 24       Negative                                                []
# 25       Negative                                                []
# 26       Positive                                                []
# 27       Negative                                                []
# 28       Negative                                                []
# 29        Neutral                                                []
# 30       Negative                                                []
# 31        Neutral                                                []
# 32       Positive                                                []
# 33       Negative                             [(Uhuru, POLITICIAN)]
# 34       Positive                                                []
# 35       Negative                                                []
# 36        Neutral                                                []
# 37       Negative                                                []
# 38       Negative                          [(Shameful, POLITICIAN)]
# 39        Neutral                                                []
# 40       Negative                                                []
# 41       Negative                                                []
# 42       Positive                                                []
# 43       Negative                                                []
# 44       Negative                             [(Uhuru, POLITICIAN)]
# 45        Neutral                                                []
# 46       Negative                                                []
# 47        Neutral                                                []
# 48        Neutral                                                []
# 49       Negative                                                []

# %% [markdown]
# ## Get names and political parties

# %%
fin_data["Parties"] = fin_data["tags"].apply(lambda x: get_parties(x))
fin_data["Politicians"] = fin_data["tags"].apply(lambda x: get_names(x))
fin_data[50:100]
# Out:
#                                               Comment  \
# 50  If all chopper is 300M or even below that, how...
# 51  Endeleeni kuongea mambo ya helicopter badala y...
# 52  The helicopter can be sold to scrape dealers t...
# 53  That's a lie and anyway who cares . Where is t...
# 54  they had it in mind when they were doing it, l...
# 55  Non of our business use kemsa stolen billions ...
# 56  A very good excuse to use your long forgotten ...
# 57  If BBI each MCA was given 2m car grant to pass...
# 58  You are talking of helicopter, while some tax ...
# 59  And how much costs Kenyans whose businesses ge...
# 60  But they have 2B they take away daily,and ofco...
# 61  What is 10m to this politicians mere pocket ch...
# 62  Hebatulla and Impala can replace it for 5k.......
# 63  What's the value of a 10M worth windshield tha...
# 64  and how much does it cost to lower the food pr...
# 65  What is the price of the gas let that sort it out
# 66  So we shouldn't think about the rapid increse ...
# 67                          They should pay the price
# 68  Inanihusu wapi ?zinangukanga na zinachomeka Th...
# 69               Tax payers hard earned cash #smh! 😪😪
# 70  Mwanachi anazidi kuteseka but now with unneces...
# 71  It is priceless to replace businesses and life...
# 72                              Deep state can afford
# 73  Let's wait and see how you are going to deal w...
# 74  What is the purpose of holding presidential el...
# 75  Which country has better business environment ...
# 76     How will that bring food to frustrated kenyans
# 77  They can have that replaced for less than 90k ...
# 78  The helicopter is fully insured. But the peopl...
# 79                         Insurance will pay for it.
# 80  Do these leaders know how much loss we incurre...
# 81                       How much is a new helicopter
# 82  No police traffic in air ,they can operate wit...
# 83  Meanwhile tell us the cost that it costed to r...
# 84  How does it concern hustler's who are struggli...
# 85  How much it costs for damaged Rutos vehicles i...
# 86              Ruto and his guys should pay for this
# 87  Lie,,i know someone in Nanyuki who can do it w...
# 88  Let the perpetrators and their sponsors pay al...
# 89  If he is still complaining on the repairs then...
# 90                Insurance will do that.... We know,
# 91  I'm still waiting for Baba to return the chopp...
# 92  They can use wheelbarrow instaed #bottomupappr...
# 93                         Let them pay for ignorance
# 94  Why don't they visit kariobangi where the cost...
# 95  What of windshield destroy through just an acc...
# 96  How about you raise the cost to like 1 billion...
# 97                                      It is insured
# 98  That's little to their owner. He will pay on t...
# 99           ISN'T THAT POCKET CHANGE TO THEM....🙄🙄??
#
#                                                 Lemma  Vader_Sentiment  \
# 50                  chopper even , screen , tell bird           0.0000
# 51    Endeleeni kuongea mambo ya helicopter badala...           0.2023
# 52      helicopter sold scrape dealer beyond repair .           0.0000
# 53     's lie anyway cares . fuel wacheni ujinga ....           0.4588
# 54    mind , let replace air shield , hyo syo guru...           0.0000
# 55    Non business use kemsa stolen billion purcha...          -0.4939
# 56      good excuse use long forgotten paybill number           0.4890
# 57          BBI MCA given car grant pass . drop ocean           0.1027
# 58        talking helicopter , tax payer going hungry           0.0000
# 59    much cost Kenyans whose business get destroy...          -0.1531
# 60    B take away daily , ofcourse Junet repair ai...           0.0000
# 61                    politician mere pocket change .           0.0000
# 62    Hebatulla Impala replace k ..... good one ca...           0.4404
# 63    's value worth windshield easily broken mere...           0.3818
# 64    much cost lower food price economy level com...           0.2263
# 65                                 price gas let sort           0.0000
# 66    n't think rapid increse price basic need ( i...           0.0000
# 67                                          pay price          -0.1027
# 68    Inanihusu wapi ? zinangukanga na zinachomeka...          -0.3400
# 69                       Tax payer hard earned cash !          -0.4574
# 70    Mwanachi anazidi kuteseka unnecessary thing ...           0.1901
# 71    priceless replace business life lost 'Resist...          -0.6310
# 72                                  Deep state afford           0.0000
# 73    Let 's wait see going deal two third gender ...           0.3818
# 74    purpose holding presidential election mean R...          -0.5093
# 75    country good business environment hiring cho...           0.4404
# 76                       bring food frustrated kenyan          -0.5267
# 77                    replaced less k industrial area           0.0000
# 78    helicopter fully insured . people behind fac...           0.0000
# 79                                    Insurance pay .          -0.1027
# 80                   leader know much loss incurred ?          -0.3182
# 81                                much new helicopter           0.0000
# 82      police traffic air , operate without replaced          -0.2960
# 83    Meanwhile tell us cost costed repair deputy ...           0.0000
# 84    concern hustler 's struggling high cost livi...          -0.4215
# 85         much costs damaged Rutos vehicle Kondele ?          -0.4404
# 86                                       Ruto guy pay          -0.1027
# 87                Lie , ,i know someone Nanyuki k ...           0.0000
# 88    Let perpetrator sponsor pay cost . Plus serv...          -0.3400
# 89    still complaining repair doest deserve chopp...          -0.2023
# 90                              Insurance .... know ,           0.0000
# 91      'm still waiting Baba return chopper leased .           0.0000
# 92                            use wheelbarrow instaed           0.0000
# 93                                  Let pay ignorance          -0.4404
# 94                   n't visit kariobangi cost low ..          -0.3384
# 95    windshield destroy accident something part y...          -0.7650
# 96    raise cost like billion ? Nansense ! n't con...           0.6526
# 97                                            insured           0.0000
# 98                       's little owner . pay behalf          -0.1027
# 99                         N'T POCKET CHANGE .... ? ?           0.0000
#
#    Vader_Analysis                                       tags Parties  \
# 50        Neutral                                         []    None
# 51       Positive  [(Ruto, POLITICIAN), (Raila, POLITICIAN)]    None
# 52        Neutral                                         []    None
# 53       Positive                                         []    None
# 54        Neutral                                         []    None
# 55       Negative                                         []    None
# 56       Positive                                         []    None
# 57       Positive                                         []    None
# 58        Neutral                                         []    None
# 59       Negative                      [(Raila, POLITICIAN)]    None
# 60        Neutral                                         []    None
# 61        Neutral                                         []    None
# 62       Positive                                         []    None
# 63       Positive                                         []    None
# 64       Positive                                         []    None
# 65        Neutral                                         []    None
# 66        Neutral                                         []    None
# 67       Negative                                         []    None
# 68       Negative                                         []    None
# 69       Negative                                         []    None
# 70       Positive                                         []    None
# 71       Negative                      [(Raila, POLITICIAN)]    None
# 72        Neutral                                         []    None
# 73       Positive                                         []    None
# 74       Negative                      [(Raila, POLITICIAN)]    None
# 75       Positive                                         []    None
# 76       Negative                                         []    None
# 77        Neutral                                         []    None
# 78        Neutral                                         []    None
# 79       Negative                                         []    None
# 80       Negative                                         []    None
# 81        Neutral                                         []    None
# 82       Negative                                         []    None
# 83        Neutral                                         []    None
# 84       Negative                                         []    None
# 85       Negative                                         []    None
# 86       Negative                       [(Ruto, POLITICIAN)]    None
# 87        Neutral                                         []    None
# 88       Negative                                         []    None
# 89       Negative                                         []    None
# 90        Neutral                                         []    None
# 91        Neutral                       [(Baba, POLITICIAN)]    None
# 92        Neutral                                         []    None
# 93       Negative                                         []    None
# 94       Negative                                         []    None
# 95       Negative                                         []    None
# 96       Positive                                         []    None
# 97        Neutral                                         []    None
# 98       Negative                                         []    None
# 99        Neutral                                         []    None
#
#       Politicians
# 50             []
# 51  [Ruto, Raila]
# 52             []
# 53             []
# 54             []
# 55             []
# 56             []
# 57             []
# 58             []
# 59        [Raila]
# 60             []
# 61             []
# 62             []
# 63             []
# 64             []
# 65             []
# 66             []
# 67             []
# 68             []
# 69             []
# 70             []
# 71        [Raila]
# 72             []
# 73             []
# 74        [Raila]
# 75             []
# 76             []
# 77             []
# 78             []
# 79             []
# 80             []
# 81             []
# 82             []
# 83             []
# 84             []
# 85             []
# 86         [Ruto]
# 87             []
# 88             []
# 89             []
# 90             []
# 91         [Baba]
# 92             []
# 93             []
# 94             []
# 95             []
# 96             []
# 97             []
# 98             []
# 99             []

# %%
poll_counts = fin_data["Politicians"][0].value_counts()
poll_counts
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11384/927258733.py in <module>
# ----> 1 poll_counts = fin_data["Politicians"][0].value_counts()
#       2 poll_counts
#
# AttributeError: 'list' object has no attribute 'value_counts'
